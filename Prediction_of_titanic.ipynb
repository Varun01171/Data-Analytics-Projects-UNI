# %% [markdown]
# <a href="https://colab.research.google.com/github/Varun01171/Data-Analytics-Projects-UNI/blob/Pipelines/Prediction_of_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
import pandas as pd

# Assume user input
# Assuming these are common Titanic dataset columns for demonstration
feature_names = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
raw_data = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'], dtype=object).reshape(1,7)
test_input2 = pd.DataFrame(raw_data, columns=feature_names)

# %%
pipe.predict(test_input2)
# Out:
# array([0])
